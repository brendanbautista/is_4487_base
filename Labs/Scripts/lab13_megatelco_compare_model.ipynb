# %% [markdown]
# <a href="https://colab.research.google.com/github/brendanbautista/is_4487_base/blob/main/Labs/Scripts/lab13_megatelco_compare_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IS 4487 Lab 13
#
# ## Outline
#
# What do you need to know for this module's project?
#
# 1.  Use the model to predict on a new dataset (without the target), then use these predictions to identify those who should be called--a contact list.
# 2.  Make a recommendation to the Director of Sales based on your analytic work.
# 3.  Compare the output of the Classification Tree to an Ensemble method (XGBoost)
#
# **NOTE:** For the module 7 project you will predict answering for prospective customers (who have not yet been called). Consequently, the assignment requires an additional dataset, customer_data.csv, that you will need to download and move into your project folder.
#
# <a href="https://colab.research.google.com/github/Stan-Pugsley/is_4487_base/blob/main/Labs/Scripts/lab13_megatelco_compare_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Load Libraries
#
# In this class we will be using
# - Pandas
# - Scikitlearn
# - Matplotlib

# %%
import pandas as pd
import matplotlib as mpl
import seaborn as sns

from sklearn.tree import DecisionTreeClassifier, export_graphviz # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics  #Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## Getting data into Pandas
#
# In this case we will load data from the statsmodels.org library
#
# See the Canvas assignments and lectures for a description of the Megatelco data
#
# **Note:** you will need to enter a code supplied by Google in the next step.

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

df = pd.read_csv (r'/content/megatelco_leave_survey (1).csv')
# Out:
# Mounted at /content/gdrive

# %%
#look at the top rows
df.head(10)
# Out:
#   college  income  overage  leftover   house  handset_price  \
# 0     one   23859       70         0  519105            154
# 1    zero   72466       67        16  271182            262
# 2    zero   30883       60         0  647281            211
# 3     one   44512        0        22  754958            232
# 4    zero   70535        0         0  653421            310
# 5    zero  143987        0        56  896544            778
# 6     one   96668       79        24  259329            365
# 7     one   50083        0         0  160335            266
# 8     one  104392        0         0  247836            778
# 9     one   37852        0        74  264893            857
#
#    over_15mins_calls_per_month  average_call_duration reported_satisfaction  \
# 0                          5.0                      8                   low
# 1                          5.0                      5                   low
# ...

# %%
#look at the datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   college                      5000 non-null   object
#  1   income                       5000 non-null   int64
#  2   overage                      5000 non-null   int64
#  3   leftover                     5000 non-null   int64
#  4   house                        5000 non-null   int64
#  5   handset_price                5000 non-null   int64
#  6   over_15mins_calls_per_month  4997 non-null   float64
#  7   average_call_duration        5000 non-null   int64
#  8   reported_satisfaction        5000 non-null   object
#  9   reported_usage_level         5000 non-null   object
#  10  considering_change_of_plan   5000 non-null   object
#  11  leave                        5000 non-null   object
#  12  id                           5000 non-null   int64
# ...

# %%
#describe the data before cleaning it
df.describe()
# Out:
#               income      overage     leftover           house  handset_price  \
# count    5000.000000  5000.000000  5000.000000     5000.000000   5.000000e+03
# mean    79912.948400    85.119200    24.243600   493656.326600   7.876236e+02
# std     41703.042384    85.655622    26.847496   254287.193865   2.828291e+04
# min    -28811.000000     0.000000     0.000000  -796132.000000   1.300000e+02
# 25%     41592.500000     0.000000     0.000000   260586.500000   2.190000e+02
# 50%     75041.500000    59.000000    15.000000   451865.500000   3.220000e+02
# 75%    115475.000000   177.000000    42.000000   701608.750000   5.280000e+02
# max    159938.000000   335.000000    89.000000  1000000.000000   2.000234e+06
#
#        over_15mins_calls_per_month  average_call_duration            id
# count                  4997.000000            5000.000000   5000.000000
# mean                      7.744647               5.958800  10036.639400
# ...

# %% [markdown]
# ## Clean up the data
# Did you notice anything unusual about the "house" amounts?
#
# How about the handset price and income?
#
# Clean up the data in a  new datafram named "df_clean"

# %%
#delete rows with outlier data; put it in a new dataframe
df_clean = df[(df['house'] > 0) & (df['income'] > 0) & (df['handset_price'] < 1000)]

#delete any rows with missing values in the clean dataframe
df_clean = df_clean.dropna()

df_clean.describe()
# Out:
#               income      overage     leftover           house  handset_price  \
# count    4994.000000  4994.000000  4994.000000     4994.000000    4994.000000
# mean    79911.270525    85.114738    24.244694   493946.252903     387.616340
# std     41683.689543    85.610045    26.844259   253599.007645     213.659555
# min     20028.000000     0.000000     0.000000   150305.000000     130.000000
# 25%     41591.500000     0.000000     0.000000   260741.500000     219.000000
# 50%     74962.500000    59.000000    15.000000   452087.500000     322.000000
# 75%    115497.000000   177.000000    42.000000   701612.250000     528.000000
# max    159938.000000   335.000000    89.000000  1000000.000000     899.000000
#
#        over_15mins_calls_per_month  average_call_duration            id
# count                  4994.000000            4994.000000   4994.000000
# mean                      7.739287               5.957549  10032.925110
# ...

# %% [markdown]
# # Standardize attributes
#
# - Convert "college" to 0,1
# - Convert reported_satisfaction to 1,2,3
# - Convert reported_usage_level to 1,2,3
# - Convert considering_change_of_plan to 0,1
# - Convert leave to 0,1
#
# I'm going to leave the "leave" variable in place, just in case I need the original value

# %%
df_clean.loc[df_clean['college'] == 'one', 'college'] = "1"
df_clean.loc[df_clean['college'] == 'zero', 'college'] = "0"
df_clean.loc[df_clean['reported_satisfaction'] == 'low', 'reported_satisfaction'] = "1"
df_clean.loc[df_clean['reported_satisfaction'] == 'avg', 'reported_satisfaction'] = "2"
df_clean.loc[df_clean['reported_satisfaction'] == 'high', 'reported_satisfaction'] = "3"
df_clean.loc[df_clean['reported_usage_level'] == 'low', 'reported_usage_level'] = "1"
df_clean.loc[df_clean['reported_usage_level'] == 'avg', 'reported_usage_level'] = "2"
df_clean.loc[df_clean['reported_usage_level'] == 'high', 'reported_usage_level'] = "3"
df_clean.loc[df_clean['considering_change_of_plan'] == 'yes', 'considering_change_of_plan'] = "1"
df_clean.loc[df_clean['considering_change_of_plan'] == 'no', 'considering_change_of_plan'] = "0"
df_clean.loc[df_clean['considering_change_of_plan'] == 'maybe', 'considering_change_of_plan'] = "0.5"

df_clean['college'] = df_clean['college'].astype('int')
df_clean['reported_satisfaction'] = df_clean['reported_satisfaction'].astype('int')
df_clean['reported_usage_level'] = df_clean['reported_usage_level'].astype('int')
df_clean['considering_change_of_plan'] = df_clean['considering_change_of_plan'].astype('float')

#Add new field with binary value for leave
df_clean['leave_flag'] = df_clean['leave'].str.replace('STAY','0')
df_clean['leave_flag'] = df_clean['leave_flag'].str.replace('LEAVE','1')
df_clean['leave_flag'] = df_clean['leave_flag'].astype('int')
df_clean['leave_flag'] = df_clean['leave_flag'].astype('bool')

df_clean.head(10)
# Out:
#    college  income  overage  leftover   house  handset_price  \
# 0        1   23859       70         0  519105            154
# 1        0   72466       67        16  271182            262
# 2        0   30883       60         0  647281            211
# 3        1   44512        0        22  754958            232
# 4        0   70535        0         0  653421            310
# 5        0  143987        0        56  896544            778
# 6        1   96668       79        24  259329            365
# 7        1   50083        0         0  160335            266
# 8        1  104392        0         0  247836            778
# 9        1   37852        0        74  264893            857
#
#    over_15mins_calls_per_month  average_call_duration  reported_satisfaction  \
# 0                          5.0                      8                      1
# 1                          5.0                      5                      1
# ...

# %% [markdown]
# # Convert attributes to factors
#
# - Leave
# - College
# - Reported satisfaction
# - Reported usage level
# - Considering change of plan

# %%
df_clean['leave'] = df_clean['leave'].astype('category')
df_clean['college'] = df_clean['college'].astype('category')
df_clean['reported_satisfaction'] = df_clean['reported_satisfaction'].astype('category')
df_clean['reported_usage_level'] = df_clean['reported_usage_level'].astype('category')
df_clean['considering_change_of_plan'] = df_clean['considering_change_of_plan'].astype('category')

df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4994 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   college                      4994 non-null   category
#  1   income                       4994 non-null   int64
#  2   overage                      4994 non-null   int64
#  3   leftover                     4994 non-null   int64
#  4   house                        4994 non-null   int64
#  5   handset_price                4994 non-null   int64
#  6   over_15mins_calls_per_month  4994 non-null   float64
#  7   average_call_duration        4994 non-null   int64
#  8   reported_satisfaction        4994 non-null   category
#  9   reported_usage_level         4994 non-null   category
#  10  considering_change_of_plan   4994 non-null   category
#  11  leave                        4994 non-null   category
#  12  id                           4994 non-null   int64
# ...

# %% [markdown]
# # What is the base probability of leaving?
#
# If we use no model at all, how good is our chance of predicting someone leaving?

# %%
df_clean['leave_flag'].mean()
# Out:
# 0.4941930316379656

# %% [markdown]
# ## Split the dataset
#
# Split dataset into 80% training data and 20% test data

# %%
# split the datafram into independent (x) and dependent (predicted) attributes (y)
x = df_clean[['income','house','college','overage','leftover','handset_price','over_15mins_calls_per_month','average_call_duration','reported_satisfaction','reported_usage_level','considering_change_of_plan']]
y = df_clean['leave_flag']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# ## Fit a basic tree model and create a confusion matrix
#
# Use all available attributes

# %%
full_tree = DecisionTreeClassifier(criterion="entropy", max_depth=4)

# Create Decision Tree Classifer
full_tree = full_tree.fit(x_train,y_train)

# Use the tree to predict "leave"
y_predict = full_tree.predict(x_test)

# %% [markdown]
# ## What is the accuracy on the test dataset?

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_predict))
# Out:
# Accuracy: 0.7027027027027027

# %% [markdown]
# ## View the confusion matrix

# %%
# create a confusion matrix
full_tree_matrix = confusion_matrix(y_test, y_predict)
print(full_tree_matrix)

#Create a heatmap from our confusion matrix
cm = sns.heatmap(full_tree_matrix, annot=True, fmt='d',cmap='Reds')

cm.set_title('Confusion Matrix');
cm.set_xlabel('Predicted')
cm.set_ylabel('Observered (Actual)');

cm.xaxis.set_ticklabels(['Stay','Leave'])
cm.yaxis.set_ticklabels(['Stay','Leave'])
# Out:
# [[321 202]
#  [ 95 381]]
# [Text(0, 0.5, 'Stay'), Text(0, 1.5, 'Leave')]

# %% [markdown]
# # Apply the model to a new dataset
#
# In this dataset, we don't know answer.  We need to predict if they will stay or leave

# %%
#Import the new data
df_new = pd.read_csv (r'/content/megatelco_new_customer_data.csv')

# %%
#Preview the new data
df_new.describe()
# Out:
#               income     overage   leftover          house  handset_price  \
# count      24.000000   24.000000  24.000000      24.000000      24.000000
# mean    83705.958333  110.208333  28.625000  451115.500000     385.125000
# std     40593.334190   97.638632  29.793219  205207.606472     231.486184
# min     20392.000000    0.000000   0.000000  173038.000000     132.000000
# 25%     46900.000000    0.000000   0.000000  263864.000000     203.750000
# 50%     90135.500000  112.000000  17.500000  443579.000000     338.000000
# 75%    120707.500000  197.750000  50.750000  594438.500000     416.250000
# max    143929.000000  252.000000  87.000000  853464.000000     888.000000
#
#        over_15mins_calls_per_month  average_call_duration            id
# count                     24.00000              24.000000     24.000000
# mean                      11.62500               5.125000  11275.583333
# std                       10.66409               4.099973   4947.953779
# ...

# %%
#delete rows with outlier data; put it in a new dataframe
df_clean_new = df_new[(df_new['house'] > 0) & (df_new['income'] > 0) & (df_new['handset_price'] < 1000)]

#delete any rows with missing values in the clean dataframe
df_clean_new = df_clean_new.dropna()

#standardize attributes
df_clean_new.loc[df_clean_new['college'] == 'one', 'college'] = "1"
df_clean_new.loc[df_clean_new['college'] == 'zero', 'college'] = "0"
df_clean_new.loc[df_clean_new['reported_satisfaction'] == 'low', 'reported_satisfaction'] = "1"
df_clean_new.loc[df_clean_new['reported_satisfaction'] == 'avg', 'reported_satisfaction'] = "2"
df_clean_new.loc[df_clean_new['reported_satisfaction'] == 'high', 'reported_satisfaction'] = "3"
df_clean_new.loc[df_clean_new['reported_usage_level'] == 'low', 'reported_usage_level'] = "1"
df_clean_new.loc[df_clean_new['reported_usage_level'] == 'avg', 'reported_usage_level'] = "2"
df_clean_new.loc[df_clean_new['reported_usage_level'] == 'high', 'reported_usage_level'] = "3"
df_clean_new.loc[df_clean_new['considering_change_of_plan'] == 'yes', 'considering_change_of_plan'] = "1"
df_clean_new.loc[df_clean_new['considering_change_of_plan'] == 'no', 'considering_change_of_plan'] = "0"
df_clean_new.loc[df_clean_new['considering_change_of_plan'] == 'maybe', 'considering_change_of_plan'] = "0.5"

df_clean_new['college'] = df_clean_new['college'].astype('int')
df_clean_new['reported_satisfaction'] = df_clean_new['reported_satisfaction'].astype('int')
df_clean_new['reported_usage_level'] = df_clean_new['reported_usage_level'].astype('int')
df_clean_new['considering_change_of_plan'] = df_clean_new['considering_change_of_plan'].astype('float')

#There is no "leave" or "leave_flag"

df_clean_new.head(10)
# Out:
#    college  income  overage  leftover   house  handset_price  \
# 0        1   67983      191         0  207208            384
# 1        1  143929       86         0  222288            402
# 2        0   23344      252         0  285199            132
# 3        0   60984      189         0  614200            286
# 4        0  130903        0        18  576266            819
# 5        0   85716      202         0  419080            357
# 6        0   20392        0         0  589705            167
# 7        0  121711      181        64  468078            769
# 8        1   23071      222        87  357847            144
# 9        0  120373        0         6  539948            632
#
#    over_15mins_calls_per_month  average_call_duration  reported_satisfaction  \
# 0                           19                     14                      1
# 1                            4                      9                      1
# ...

# %%
# split the datafram into independent (x) and dependent (predicted) attributes (y)
x_new = df_clean_new[['income','house','college','overage','leftover','handset_price','over_15mins_calls_per_month','average_call_duration','reported_satisfaction','reported_usage_level','considering_change_of_plan']]

# %% [markdown]
# ## Predict the customers
#
# Use the tree that we created earlier
# Take the customers one by one and pass it to the model, or create a mailing by passing a batch

# %%
# Use the tree to predict "leave" for the first customer
y_new_predict = full_tree.predict(x_new.iloc[:1])

#Convert it to a dataframe
df_new_predict = pd.DataFrame(y_new_predict)

df_new_predict.head()
# Out:
#       0
# 0  True

# %% [markdown]
# ## XGBoost
#
# Refer to this page for information on XGBoost models: https://machinelearningmastery.com/develop-first-xgboost-model-python-scikit-learn/
#
# ➡️ Assignment Tasks
# - Import XGBoost
# - Copy the section of code for the tree fit and evaluation
# - Use the training dataframe that has been split
# - In the new copy of the code, replace DecisionTreeClassifier with XGBoost
# - Compare the accuracy of the two models

# %%
#import

# %%
#fit tree

# %%
#display accuracy

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_clean.drop('leave_flag', axis=1), df_clean['leave_flag'], test_size=0.2, random_state=42)

# %%
model = xgb.XGBClassifier(objective='binary:logistic', max_depth=3, learning_rate=0.1, n_estimators=100, enable_categorical=True)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
model = xgb.XGBClassifier(objective='binary:logistic', max_depth=3, learning_rate=0.1, n_estimators=100, enable_categorical=True)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 1.00

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'max_depth': [3, 5, 7], 'learning_rate': [0.01, 0.05, 0.1], 'n_estimators': [50, 100, 200]}
grid_search = GridSearchCV(model, parameters, cv=3, scoring='accuracy')
grid_search.fit(X_train, y_train)
best_model = grid_search.best_estimator_

# %%
df_clean_new['leave'] = 0

# %%
new_data_predictions = best_model.predict(df_clean_new.drop('leave_flag', axis=1, errors='ignore'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-31d021c578da> in <cell line: 1>()
# ----> 1 new_data_predictions = best_model.predict(df_clean_new.drop('leave_flag', axis=1, errors='ignore'))
#
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py in predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1551     ) -> ArrayLike:
#    1552         with config_context(verbosity=self.verbosity):
# -> 1553             class_probs = super().predict(
#    1554                 X=X,
#    1555                 output_margin=output_margin,
#
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py in predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1166             if self._can_use_inplace_predict():
#    1167                 try:
# ...

# %%
new_data_predictions = best_model.predict(df_clean_new.drop('leave_flag', axis=1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-222f18ed7379> in <cell line: 1>()
# ----> 1 new_data_predictions = best_model.predict(df_clean_new.drop('leave', axis=1))
#
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py in predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1551     ) -> ArrayLike:
#    1552         with config_context(verbosity=self.verbosity):
# -> 1553             class_probs = super().predict(
#    1554                 X=X,
#    1555                 output_margin=output_margin,
#
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py in predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1166             if self._can_use_inplace_predict():
#    1167                 try:
# -> 1168                     predts = self.get_booster().inplace_predict(
# ...

# %%
# List of features used in the model
model_features = [col for col in X_train.columns if col != 'leave']  # Exclude 'leave' if it was erroneously included

# Adjust df_clean_new to have the same features
df_clean_new_adjusted = df_clean_new[model_features]

# %%
# Assuming 'leave_flag' is the target and all other columns are features
X_train = df_clean.drop('leave_flag', axis=1)
y_train = df_clean['leave_flag']

# Re-fit the model if necessary
best_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=50, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# Assuming 'leave_flag' is your target variable
X_train = df_clean.drop(['leave_flag', 'leave'], axis=1, errors='ignore')  # Make sure 'leave' is not included as a feature
y_train = df_clean['leave_flag']

# Reinitialize and retrain your model
model = xgb.XGBClassifier(objective='binary:logistic', max_depth=3, learning_rate=0.1, n_estimators=100, enable_categorical=True)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# Making sure df_clean_new_adjusted contains only the features in X_train
df_clean_new_adjusted = df_clean_new[X_train.columns]

# Now, try predicting again
new_data_predictions = model.predict(df_clean_new_adjusted)

# %%
# Check if the features match
if not all(feature in df_clean_new_adjusted.columns for feature in X_train.columns):
    print("Feature mismatch found!")
else:
    new_data_predictions = model.predict(df_clean_new_adjusted)

# %%
# Assuming 'leave_flag' is the target variable
X_train = df_clean.drop(['leave_flag', 'leave'], axis=1, errors='ignore')  # Exclude 'leave' and 'leave_flag'
y_train = df_clean['leave_flag']

# Initialize and train the model (redefining best_model for clarity)
model = xgb.XGBClassifier(objective='binary:logistic', max_depth=3, learning_rate=0.1, n_estimators=100, enable_categorical=True)
model.fit(X_train, y_train)

# Assuming this model now becomes the 'best_model' after confirming its performance
best_model = model

# %%
# Aligning df_clean_new to match the training data
df_clean_new_adjusted = df_clean_new[list(X_train.columns)]  # Make sure columns are in the same order

# %%
# Predict using the aligned and adjusted new data
new_data_predictions = best_model.predict(df_clean_new_adjusted)

# %%
# Check if the features match
print("Training features:", X_train.columns)
print("New data features:", df_clean_new_adjusted.columns)

# Ensure there are no missing values in df_clean_new_adjusted
if df_clean_new_adjusted.isnull().any().any():
    print("Warning: Missing values found in the new data.")
else:
    # Perform the prediction
    new_data_predictions = best_model.predict(df_clean_new_adjusted)
    print("Prediction successful.")
# Out:
# Training features: Index(['college', 'income', 'overage', 'leftover', 'house', 'handset_price',
#        'over_15mins_calls_per_month', 'average_call_duration',
#        'reported_satisfaction', 'reported_usage_level',
#        'considering_change_of_plan', 'id'],
#       dtype='object')
# New data features: Index(['college', 'income', 'overage', 'leftover', 'house', 'handset_price',
#        'over_15mins_calls_per_month', 'average_call_duration',
#        'reported_satisfaction', 'reported_usage_level',
#        'considering_change_of_plan', 'id'],
#       dtype='object')
# Prediction successful.

# %%
# Predict on the adjusted new data
new_data_predictions = best_model.predict(df_clean_new_adjusted)

# %%
# Assuming `1` indicates potential leavers
df_clean_new['predicted_leave'] = new_data_predictions
contact_list = df_clean_new[df_clean_new['predicted_leave'] == 1]

# %%
from sklearn.metrics import accuracy_score

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.2%}")
# Out:
# Model Accuracy: 100.00%

# %%
import matplotlib.pyplot as plt

# Get feature importances
feature_importances = best_model.feature_importances_

# Create a Series to make it easier to plot
importances = pd.Series(feature_importances, index=X_train.columns)

# Plot feature importances
importances.sort_values().plot(kind='barh', figsize=(8, 6))
plt.title('Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Stay', 'Leave'], yticklabels=['Stay', 'Leave'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
